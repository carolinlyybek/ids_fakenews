# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/fake-and-real-news-dataset/True.csv
# /kaggle/input/fake-and-real-news-dataset/Fake.csv

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
real = pd.read_csv("../input/fake-and-real-news-dataset/True.csv")
fake = pd.read_csv("../input/fake-and-real-news-dataset/Fake.csv")

fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %% [markdown]
# First, I'm going to make some wordclouds to take a look at the data

# %%
from wordcloud import WordCloud, STOPWORDS
fake_words = ""
stopwords = set(STOPWORDS)
stopwords.add("wa")
stopwords.add("thi")
for text in fake.text.values:
    text = str(text)
    words = text.split()
    fake_words += " ".join([(i.lower() + " ") for i in words])

# %% [markdown]
# ## Fake news word cloud

# %%
fake_cloud = WordCloud(width = 500, height = 500, background_color = 'white', stopwords = stopwords, min_font_size = 10)
fake_cloud.generate(fake_words)

plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(fake_cloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.title("Fake news")
  
plt.show()

# %% [markdown]
# ## Real news word cloud

# %%
real_words = ""
for text in real.text.values:
    text = str(text)
    words = text.split()
    real_words += " ".join([(i.lower() + " ") for i in words])
real_cloud = WordCloud(width = 500, height = 500, background_color = 'white', stopwords = stopwords, min_font_size = 10)
real_cloud.generate(real_words)

plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(real_cloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.title("Real news")
  
plt.show()

# %% [markdown]
# Merge real & fake data, clean it, and split it into train/test/validation.

# %%
real["fake?"] = np.zeros(len(real))
fake["fake?"] = np.ones(len(fake))
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  fake?
# 0  December 31, 2017    1.0
# 1  December 31, 2017    1.0
# 2  December 30, 2017    1.0
# 3  December 29, 2017    1.0
# 4  December 25, 2017    1.0

# %%
from sklearn.utils import shuffle

news = real.append(fake)
news = shuffle(news)
news
# Out:
#                                                    title  \
# 1263   California attorney general to sue over Trump ...
# 21681  HOW OBAMA’S NEW DOJ PLANS TO BYPASS CONGRESS T...
# 14642  Suspicious object found with body in Stockholm...
# 17143  SCRUBBED CLEAN? HILLARY CLINTON TO FINALLY TUR...
# 4047    ‘I Don’t Rent To N*****s’: Smoking Gun Proves...
# ...                                                  ...
# 18487  As sanctions bite, North Korean workers leave ...
# 1771   Ryan says tax reform outline reflects consensu...
# 8532    POLL: Bristol Palin Wants To Know Whose Voice...
# 18801  French court jails woman who sent money to son...
# 7344    Trump Issues Bizarre Threat To Ted Cruz’s Wif...
#
#                                                     text          subject  \
# 1263   SAN FRANCISCO (Reuters) - California Attorney ...     politicsNews
# 21681  Eric Holder in a skirt Obama s Department of J...        left-news
# 14642  STOCKHOLM (Reuters) - A man was found dead on ...        worldnews
# 17143  I appears that Hillary Clinton is really in a ...  Government News
# 4047   New video has surfaced adding to the mountain ...             News
# ...                                                  ...              ...
# 18487  DANDONG, China (Reuters) - North Korean worker...        worldnews
# 1771   WASHINGTON (Reuters) - U.S. House of Represent...     politicsNews
# 8532   Bristol Palin had something to say and pondere...             News
# 18801  PARIS (Reuters) - A French court on Thursday f...        worldnews
# 7344   Donald Trump has once again taken to Twitter t...             News
#
#                       date  fake?
# 1263     October 13, 2017     0.0
# 21681          Jun 1, 2015    1.0
# 14642   November 16, 2017     0.0
# 17143         Aug 12, 2015    1.0
# 4047      October 25, 2016    1.0
# ...                    ...    ...
# 18487     October 2, 2017     0.0
# 1771   September 13, 2017     0.0
# 8532      January 26, 2016    1.0
# 18801  September 28, 2017     0.0
# 7344        March 23, 2016    1.0
#
# [44898 rows x 5 columns]

# %%
import string
def clean_text(text):
    words = str(text).split()
    words = [i.lower() + " " for i in words]
    words = " ".join(words)
    words = words.translate(words.maketrans('', '', string.punctuation))
    return words

news['text'] = news['text'].apply(clean_text)
news.head()
# Out:
#                                                    title  \
# 1263   California attorney general to sue over Trump ...
# 21681  HOW OBAMA’S NEW DOJ PLANS TO BYPASS CONGRESS T...
# 14642  Suspicious object found with body in Stockholm...
# 17143  SCRUBBED CLEAN? HILLARY CLINTON TO FINALLY TUR...
# 4047    ‘I Don’t Rent To N*****s’: Smoking Gun Proves...
#
#                                                     text          subject  \
# 1263   san  francisco  reuters    california  attorne...     politicsNews
# 21681  eric  holder  in  a  skirt  obama  s  departme...        left-news
# 14642  stockholm  reuters    a  man  was  found  dead...        worldnews
# 17143  i  appears  that  hillary  clinton  is  really...  Government News
# 4047   new  video  has  surfaced  adding  to  the  mo...             News
#
#                      date  fake?
# 1263    October 13, 2017     0.0
# 21681         Jun 1, 2015    1.0
# 14642  November 16, 2017     0.0
# 17143        Aug 12, 2015    1.0
# 4047     October 25, 2016    1.0

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(news)
train, validation = train_test_split(train, test_size = 0.2)
print(len(train), len(validation), len(test) )
# Out:
# 26938 6735 11225

# %%
train
# Out:
#                                                    title  \
# 21179  U.S.-led forces acknowledge killing 61 more ci...
# 13326  Honduran presidential result due at 9 pm: elec...
# 5461   Trump national security aide Flynn resigns ove...
# 13778  LOL! The Woman Who Couldn’t Be Bothered With P...
# 6933   Trump targets another company, draws Sanders' ...
# ...                                                  ...
# 16635  Mugabe would have rejected WHO role, says spok...
# 14613  Suicide bomber kills nine near Afghan politica...
# 11458  Myanmar, accused of crackdown, invited to U.S....
# 16307  BREAKING: TRUMP PICKS Private Sector Titans Fo...
# 2700    Kellyanne Conway Says Trump Should Be Treated...
#
#                                                     text          subject  \
# 21179  washington  reuters    the  usled  coalition  ...        worldnews
# 13326  tegucigalpa  reuters    honduras  will  publis...        worldnews
# 5461   washington  reuters    president  donald  trum...     politicsNews
# 13778  ironically  the  two  issues  that  catapulted...         politics
# 6933   washington  reuters    presidentelect  donald ...     politicsNews
# ...                                                  ...              ...
# 16635  harare  reuters    robert  mugabe  would  have...        worldnews
# 14613  kabul  reuters    a  suicide  bomb  attack  in...        worldnews
# 11458  washington  reuters    the  myanmar  military ...        worldnews
# 16307  hedge  fund  manager  steve  mnuchin  said  th...  Government News
# 2700   whiny  white  house  advisor  kellyanne  conwa...             News
#
#                      date  fake?
# 21179  September 1, 2017     0.0
# 13326   December 1, 2017     0.0
# 5461   February 13, 2017     0.0
# 13778         Jun 1, 2016    1.0
# 6933    December 3, 2016     0.0
# ...                   ...    ...
# 16635   October 24, 2017     0.0
# 14613  November 16, 2017     0.0
# 11458  December 23, 2017     0.0
# 16307        Nov 30, 2016    1.0
# 2700     February 3, 2017    1.0
#
# [26938 rows x 5 columns]

# %% [markdown]
# Tokenize & pad text to create input data

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

vocab_size = 10000
trunc_type = "post"
pad_type = "post"
oov_tok = "<OOV>"
tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(train.text)
word_index = tokenizer.word_index

# %%
training_sequences = tokenizer.texts_to_sequences(np.array(train.text))
training_padded = pad_sequences(training_sequences,truncating=trunc_type, padding=pad_type)

max_length = len(training_padded[0])

validation_sequences = tokenizer.texts_to_sequences(np.array(validation.text))
validation_padded = pad_sequences(validation_sequences, padding=pad_type, truncating=trunc_type, maxlen = max_length)

# %%
train_x = np.copy(training_padded)
validate_x = np.copy(validation_padded)
train_y = train['fake?'].values
validate_y = validation['fake?'].values

# %%
print(len(train_x), len(train_y))
# Out:
# 26938 26938

# %% [markdown]
# Use KerasTuner for Hyperparameter tuning for our Sequential Tensorflow model.

# %%
# !pip install -U keras-tuner
# Out:
# Collecting keras-tuner
#   Downloading keras-tuner-1.0.1.tar.gz (54 kB)
#      |████████████████████████████████| 54 kB 1.2 MB/s eta 0:00:011
# Requirement already satisfied, skipping upgrade: future in /opt/conda/lib/python3.7/site-packages (from keras-tuner) (0.18.2)
# Requirement already satisfied, skipping upgrade: numpy in /opt/conda/lib/python3.7/site-packages (from keras-tuner) (1.18.1)
# Requirement already satisfied, skipping upgrade: tabulate in /opt/conda/lib/python3.7/site-packages (from keras-tuner) (0.8.7)
# Collecting terminaltables
#   Downloading terminaltables-3.1.0.tar.gz (12 kB)
# Requirement already satisfied, skipping upgrade: colorama in /opt/conda/lib/python3.7/site-packages (from keras-tuner) (0.4.3)
# Requirement already satisfied, skipping upgrade: tqdm in /opt/conda/lib/python3.7/site-packages (from keras-tuner) (4.45.0)
# Requirement already satisfied, skipping upgrade: requests in /opt/conda/lib/python3.7/site-packages (from keras-tuner) (2.23.0)
# Requirement already satisfied, skipping upgrade: scipy in /opt/conda/lib/python3.7/site-packages (from keras-tuner) (1.4.1)
# Requirement already satisfied, skipping upgrade: scikit-learn in /opt/conda/lib/python3.7/site-packages (from keras-tuner) (0.22.2.post1)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->keras-tuner) (2.9)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->keras-tuner) (2020.4.5.1)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->keras-tuner) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->keras-tuner) (1.24.3)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /opt/conda/lib/python3.7/site-packages (from scikit-learn->keras-tuner) (0.14.1)
# Building wheels for collected packages: keras-tuner, terminaltables
#   Building wheel for keras-tuner (setup.py) ... done
#   Created wheel for keras-tuner: filename=keras_tuner-1.0.1-py3-none-any.whl size=73198 sha256=e5d0bface7ac6d298ea18eab4ec5e17310af17664a7f7a0711fee1bbcaf4b389
#   Stored in directory: /root/.cache/pip/wheels/0b/cf/2f/1a1749d3a3650fac3305a8d7f9237b6de7c41068e2f8520ca2
#   Building wheel for terminaltables (setup.py) ... done
#   Created wheel for terminaltables: filename=terminaltables-3.1.0-py3-none-any.whl size=15354 sha256=296bd6bf01630c20d01987a91db5a07c104e683f8ed04999b79681b2eb012bae
#   Stored in directory: /root/.cache/pip/wheels/ba/ad/c8/2d98360791161cd3db6daf6b5e730f34021fc9367d5879f497
# Successfully built keras-tuner terminaltables
# Installing collected packages: terminaltables, keras-tuner
# Successfully installed keras-tuner-1.0.1 terminaltables-3.1.0
# WARNING: You are using pip version 20.1; however, version 20.1.1 is available.
# You should consider upgrading via the '/opt/conda/bin/python3.7 -m pip install --upgrade pip' command.

# %%
from kerastuner.tuners import RandomSearch

def build_model(hp):
    model = tf.keras.Sequential([
        tf.keras.layers.Embedding(vocab_size, hp.Int('units', min_value = 5, max_value = 200, step = 25), input_length=max_length),
        tf.keras.layers.Conv1D(16, 5, activation='relu'),
        tf.keras.layers.GlobalMaxPooling1D(),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    model.compile(loss='binary_crossentropy',
                      optimizer=tf.keras.optimizers.Adam(hp.Choice('learning_rate',
                      values=[1e-2, 1e-3, 1e-4])), 
                      metrics=['accuracy'])
    return model

tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=5,
    executions_per_trial=3)

# history = model.fit(train_x, train_y, epochs = 30, validation_data = (validate_x, validate_y),
#                    callbacks=[tf.keras.callbacks.EarlyStopping('val_loss', patience=6)])

# %%
tuner.search(train_x, train_y, epochs = 3,verbose = 2,validation_data = (validate_x, validate_y), callbacks=[tf.keras.callbacks.EarlyStopping('val_loss', patience=2)])
# Out:
# Train on 26938 samples, validate on 6735 samples
# Epoch 1/3
# 26938/26938 - 38s - loss: 0.0311 - accuracy: 0.9901 - val_loss: 0.0106 - val_accuracy: 0.9964
# Epoch 2/3
# 26938/26938 - 33s - loss: 0.0082 - accuracy: 0.9981 - val_loss: 0.0023 - val_accuracy: 0.9990
# Epoch 3/3
# 26938/26938 - 33s - loss: 0.0064 - accuracy: 0.9988 - val_loss: 0.0013 - val_accuracy: 0.9999
# Train on 26938 samples, validate on 6735 samples
# Epoch 1/3
# 26938/26938 - 34s - loss: 0.0292 - accuracy: 0.9894 - val_loss: 0.0039 - val_accuracy: 0.9990
# Epoch 2/3
# 26938/26938 - 33s - loss: 0.0054 - accuracy: 0.9984 - val_loss: 0.0071 - val_accuracy: 0.9985
# Epoch 3/3
# 26938/26938 - 34s - loss: 0.0156 - accuracy: 0.9976 - val_loss: 0.0202 - val_accuracy: 0.9984
# Train on 26938 samples, validate on 6735 samples
# Epoch 1/3
# 26938/26938 - 34s - loss: 0.0271 - accuracy: 0.9925 - val_loss: 0.0073 - val_accuracy: 0.9985
# Epoch 2/3
# 26938/26938 - 33s - loss: 0.0092 - accuracy: 0.9977 - val_loss: 0.0144 - val_accuracy: 0.9984
# Epoch 3/3
# 26938/26938 - 33s - loss: 0.0042 - accuracy: 0.9991 - val_loss: 0.0068 - val_accuracy: 0.9985
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 219ff3ea54cadb72bf97bf2ac88476ce</span>
# <span style="color:cyan"> |-Score: 0.9991090893745422</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.01</span>
# <span style="color:blue"> |-units: 55</span>
# Train on 26938 samples, validate on 6735 samples
# Epoch 1/3
# 26938/26938 - 58s - loss: 0.0829 - accuracy: 0.9785 - val_loss: 0.0073 - val_accuracy: 0.9976
# Epoch 2/3
# 26938/26938 - 57s - loss: 0.0043 - accuracy: 0.9988 - val_loss: 0.0030 - val_accuracy: 0.9994
# Epoch 3/3
# 26938/26938 - 57s - loss: 0.0011 - accuracy: 0.9999 - val_loss: 0.0020 - val_accuracy: 0.9996
# Train on 26938 samples, validate on 6735 samples
# Epoch 1/3
# 26938/26938 - 58s - loss: 0.0847 - accuracy: 0.9713 - val_loss: 0.0047 - val_accuracy: 0.9987
# Epoch 2/3
# 26938/26938 - 57s - loss: 0.0039 - accuracy: 0.9991 - val_loss: 0.0028 - val_accuracy: 0.9993
# Epoch 3/3
# 26938/26938 - 58s - loss: 0.0011 - accuracy: 0.9999 - val_loss: 0.0020 - val_accuracy: 0.9993
# Train on 26938 samples, validate on 6735 samples
# Epoch 1/3
# 26938/26938 - 58s - loss: 0.0933 - accuracy: 0.9735 - val_loss: 0.0054 - val_accuracy: 0.9985
# Epoch 2/3
# 26938/26938 - 57s - loss: 0.0042 - accuracy: 0.9988 - val_loss: 0.0031 - val_accuracy: 0.9991
# Epoch 3/3
# 26938/26938 - 57s - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0033 - val_accuracy: 0.9991
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 9962d23acf076c3f1c34f2066bbcfadc</span>
# <span style="color:cyan"> |-Score: 0.9993071556091309</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.001</span>
# <span style="color:blue"> |-units: 105</span>
# Train on 26938 samples, validate on 6735 samples
# Epoch 1/3
# 26938/26938 - 92s - loss: 0.4994 - accuracy: 0.7354 - val_loss: 0.2774 - val_accuracy: 0.8878
# Epoch 2/3
# 26938/26938 - 91s - loss: 0.1838 - accuracy: 0.9404 - val_loss: 0.1295 - val_accuracy: 0.9602
# Epoch 3/3
# 26938/26938 - 91s - loss: 0.0980 - accuracy: 0.9720 - val_loss: 0.0886 - val_accuracy: 0.9694
# Train on 26938 samples, validate on 6735 samples
# Epoch 1/3
# 26938/26938 - 91s - loss: 0.4072 - accuracy: 0.9329 - val_loss: 0.1429 - val_accuracy: 0.9923
# Epoch 2/3
# 26938/26938 - 92s - loss: 0.0754 - accuracy: 0.9941 - val_loss: 0.0373 - val_accuracy: 0.9966
# Epoch 3/3
# 26938/26938 - 91s - loss: 0.0273 - accuracy: 0.9957 - val_loss: 0.0184 - val_accuracy: 0.9969
# Train on 26938 samples, validate on 6735 samples
# Epoch 1/3
# 26938/26938 - 92s - loss: 0.4037 - accuracy: 0.9126 - val_loss: 0.1425 - val_accuracy: 0.9835
# Epoch 2/3
# 26938/26938 - 91s - loss: 0.0728 - accuracy: 0.9931 - val_loss: 0.0332 - val_accuracy: 0.9961
# Epoch 3/3
# 26938/26938 - 92s - loss: 0.0246 - accuracy: 0.9948 - val_loss: 0.0173 - val_accuracy: 0.9964
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: a51c6ac8c71cd79efecdbe3b2aa7e791</span>
# <span style="color:cyan"> |-Score: 0.9875773787498474</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.0001</span>
# <span style="color:blue"> |-units: 180</span>
# Train on 26938 samples, validate on 6735 samples
# Epoch 1/3
# 26938/26938 - 80s - loss: 0.0695 - accuracy: 0.9848 - val_loss: 0.0052 - val_accuracy: 0.9984
# Epoch 2/3
# 26938/26938 - 80s - loss: 0.0035 - accuracy: 0.9990 - val_loss: 0.0044 - val_accuracy: 0.9984
# Epoch 3/3
# 26938/26938 - 80s - loss: 8.1910e-04 - accuracy: 0.9999 - val_loss: 0.0033 - val_accuracy: 0.9991
# Train on 26938 samples, validate on 6735 samples
# Epoch 1/3
# 26938/26938 - 81s - loss: 0.0824 - accuracy: 0.9808 - val_loss: 0.0045 - val_accuracy: 0.9990
# Epoch 2/3
# 26938/26938 - 81s - loss: 0.0028 - accuracy: 0.9993 - val_loss: 0.0030 - val_accuracy: 0.9993
# Epoch 3/3
# 26938/26938 - 80s - loss: 8.2459e-04 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 0.9991
# Train on 26938 samples, validate on 6735 samples
# Epoch 1/3
# 26938/26938 - 81s - loss: 0.0934 - accuracy: 0.9638 - val_loss: 0.0043 - val_accuracy: 0.9985
# Epoch 2/3
# 26938/26938 - 81s - loss: 0.0035 - accuracy: 0.9990 - val_loss: 0.0026 - val_accuracy: 0.9990
# Epoch 3/3
# 26938/26938 - 80s - loss: 0.0010 - accuracy: 0.9999 - val_loss: 0.0025 - val_accuracy: 0.9996
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 9059bd5065fbfed08173c21b85458da3</span>
# <span style="color:cyan"> |-Score: 0.9993071556091309</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.001</span>
# <span style="color:blue"> |-units: 155</span>
# Train on 26938 samples, validate on 6735 samples
# Epoch 1/3
# 26938/26938 - 81s - loss: 0.4611 - accuracy: 0.8407 - val_loss: 0.2240 - val_accuracy: 0.9425
# Epoch 2/3
# 26938/26938 - 81s - loss: 0.1320 - accuracy: 0.9709 - val_loss: 0.0735 - val_accuracy: 0.9887
# Epoch 3/3
# 26938/26938 - 80s - loss: 0.0417 - accuracy: 0.9936 - val_loss: 0.0231 - val_accuracy: 0.9966
# Train on 26938 samples, validate on 6735 samples
# Epoch 1/3
# 26938/26938 - 80s - loss: 0.4320 - accuracy: 0.8640 - val_loss: 0.1510 - val_accuracy: 0.9911
# Epoch 2/3
# 26938/26938 - 81s - loss: 0.0752 - accuracy: 0.9939 - val_loss: 0.0350 - val_accuracy: 0.9951
# Epoch 3/3
# 26938/26938 - 80s - loss: 0.0274 - accuracy: 0.9944 - val_loss: 0.0176 - val_accuracy: 0.9960
# Train on 26938 samples, validate on 6735 samples
# Epoch 1/3
# 26938/26938 - 81s - loss: 0.4480 - accuracy: 0.8745 - val_loss: 0.1884 - val_accuracy: 0.9599
# Epoch 2/3
# 26938/26938 - 80s - loss: 0.1004 - accuracy: 0.9854 - val_loss: 0.0456 - val_accuracy: 0.9957
# Epoch 3/3
# 26938/26938 - 80s - loss: 0.0272 - accuracy: 0.9957 - val_loss: 0.0168 - val_accuracy: 0.9967
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial complete</h1></span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 67d4338b1263dbf6f46c0b0e3f6968af</span>
# <span style="color:cyan"> |-Score: 0.9964365363121033</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.0001</span>
# <span style="color:blue"> |-units: 155</span>

# %%
tuner.results_summary()
# Out:
# <span style="color:#4527A0"><h1 style="font-size:18px">Results summary</h1></span>
# <span style="color:cyan"> |-Results in ./untitled_project</span>
# <span style="color:cyan"> |-Showing 10 best trials</span>
# <span style="color:cyan"> |-Objective(name='val_accuracy', direction='max')</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 9962d23acf076c3f1c34f2066bbcfadc</span>
# <span style="color:cyan"> |-Score: 0.9993071556091309</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.001</span>
# <span style="color:blue"> |-units: 105</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 9059bd5065fbfed08173c21b85458da3</span>
# <span style="color:cyan"> |-Score: 0.9993071556091309</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.001</span>
# <span style="color:blue"> |-units: 155</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 219ff3ea54cadb72bf97bf2ac88476ce</span>
# <span style="color:cyan"> |-Score: 0.9991090893745422</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.01</span>
# <span style="color:blue"> |-units: 55</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 67d4338b1263dbf6f46c0b0e3f6968af</span>
# <span style="color:cyan"> |-Score: 0.9964365363121033</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.0001</span>
# <span style="color:blue"> |-units: 155</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: a51c6ac8c71cd79efecdbe3b2aa7e791</span>
# <span style="color:cyan"> |-Score: 0.9875773787498474</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.0001</span>
# <span style="color:blue"> |-units: 180</span>

# %%
# model = tf.keras.Sequential([
#     tf.keras.layers.Embedding(vocab_size, 16, input_length=max_length),
#     tf.keras.layers.Conv1D(16, 5, activation='relu'),
#     tf.keras.layers.GlobalMaxPooling1D(),
#     tf.keras.layers.Dense(1, activation='sigmoid')
# ])
# model.compile(loss='binary_crossentropy',
#                   optimizer=tf.keras.optimizers.Adam(), 
#                   metrics=['accuracy'])
# history = model.fit(train_x, train_y, verbose = 2, epochs = 3, validation_data = (validate_x, validate_y),
#                    callbacks=[tf.keras.callbacks.EarlyStopping('val_loss', patience=6)])
model = tuner.get_best_models()[0]
history = model.fit(train_x, train_y, verbose = 2, epochs = 3, validation_data = (validate_x, validate_y),
                   callbacks=[tf.keras.callbacks.EarlyStopping('val_loss', patience=6)])
# Out:
# Train on 26938 samples, validate on 6735 samples
# Epoch 1/3
# 26938/26938 - 58s - loss: 5.1021e-04 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 0.9994
# Epoch 2/3
# 26938/26938 - 58s - loss: 4.2116e-04 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 0.9996
# Epoch 3/3
# 26938/26938 - 57s - loss: 3.6717e-04 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 0.9994

# %%
def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()
  
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %% [markdown]
# Classify test set and calculate accuracy

# %%
test_sequences = tokenizer.texts_to_sequences(np.array(test.text))
test_padded = pad_sequences(test_sequences, padding=pad_type, truncating=trunc_type, maxlen = max_length)

# %%
preds = np.round(model.predict(test_padded))

# %%
len(preds)
# Out:
# 11225

# %%
acc = np.sum(1 if i==j else 0 for i,j in zip(preds, test["fake?"].values)) / len(test)
print("Accuracy: ", acc )
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   """Entry point for launching an IPython kernel.
# Accuracy:  0.9989309576837416
